# %% [markdown]
# #### Chroma
# Chroma is a AI-native open-source vector database focused on developer productivity and happiness. Chroma is licensed under Apache 2.0.
#
# https://python.langchain.com/v0.2/docs/integrations/vectorstores/

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from langchain_chroma import Chroma
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings

# %%
loader = TextLoader("speech.txt")
text_loader = loader.load()

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=70)
text_splitter = splitter.split_documents(text_loader)

# %%
embedddings = OllamaEmbeddings(model="nomic-embed-text")
db = Chroma.from_documents(
    text_splitter,embedddings
)

# %%
# query
query="What a task to dedicate your lives and fortunes?"
docs =db.similarity_search(query)
docs
# Out:
# [Document(id='ca1319c0-e047-4ba2-9d14-180686ea8a47', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#  Document(id='c58002c0-1025-4c80-b301-4632274a87ca', metadata={'source': 'speech.txt'}, page_content='things which we have always carried nearest our hearts—for democracy, for the right of those who submit to authority to have a voice in their own governments, for the rights and liberties of small nations, for a universal dominion of right by such a concert of free peoples as shall bring peace and safety to all nations and make the world itself at last free.'),
#  Document(id='076031c0-974b-4ec1-adf7-9055935616b4', metadata={'source': 'speech.txt'}, page_content='It is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of all wars, civilization itself seeming to be in the balance. But the right is more precious than peace, and we shall fight for the things which we have always carried nearest our hearts—for democracy,'),
#  Document(id='c814961f-0099-4902-af2c-bc2e00e5aa4f', metadata={'source': 'speech.txt'}, page_content='it toward all who are in fact loyal to their neighbors and to the government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without')]

# %%
retriever = db.as_retriever()
docs = retriever.invoke(query)
docs
# Out:
# [Document(id='ca1319c0-e047-4ba2-9d14-180686ea8a47', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#  Document(id='c58002c0-1025-4c80-b301-4632274a87ca', metadata={'source': 'speech.txt'}, page_content='things which we have always carried nearest our hearts—for democracy, for the right of those who submit to authority to have a voice in their own governments, for the rights and liberties of small nations, for a universal dominion of right by such a concert of free peoples as shall bring peace and safety to all nations and make the world itself at last free.'),
#  Document(id='076031c0-974b-4ec1-adf7-9055935616b4', metadata={'source': 'speech.txt'}, page_content='It is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of all wars, civilization itself seeming to be in the balance. But the right is more precious than peace, and we shall fight for the things which we have always carried nearest our hearts—for democracy,'),
#  Document(id='c814961f-0099-4902-af2c-bc2e00e5aa4f', metadata={'source': 'speech.txt'}, page_content='it toward all who are in fact loyal to their neighbors and to the government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without')]

# %%
docs_and_score= db.similarity_search_with_score(query)
docs_and_score
# Out:
# [(Document(id='ca1319c0-e047-4ba2-9d14-180686ea8a47', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#   283.6481018066406),
#  (Document(id='c58002c0-1025-4c80-b301-4632274a87ca', metadata={'source': 'speech.txt'}, page_content='things which we have always carried nearest our hearts—for democracy, for the right of those who submit to authority to have a voice in their own governments, for the rights and liberties of small nations, for a universal dominion of right by such a concert of free peoples as shall bring peace and safety to all nations and make the world itself at last free.'),
#   405.0733337402344),
#  (Document(id='076031c0-974b-4ec1-adf7-9055935616b4', metadata={'source': 'speech.txt'}, page_content='It is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of all wars, civilization itself seeming to be in the balance. But the right is more precious than peace, and we shall fight for the things which we have always carried nearest our hearts—for democracy,'),
#   413.4418640136719),
#  (Document(id='c814961f-0099-4902-af2c-bc2e00e5aa4f', metadata={'source': 'speech.txt'}, page_content='it toward all who are in fact loyal to their neighbors and to the government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without'),
#   433.8305358886719)]

# %%
# save to tha disk
db = Chroma.from_documents(
    text_splitter,embedddings,persist_directory="./chroma_db"
)

# %%
# load from disk
db2 = Chroma(persist_directory="./chroma_db/", embedding_function=embedddings)
docs=db2.similarity_search(query)
docs
# Out:
# [Document(id='1da0b54b-38c2-4ff2-a971-baee3d6d6c76', metadata={'source': 'speech.txt'}, page_content='To such a task we can dedicate our lives and our fortunes, everything that we are and everything that we have, with the pride of those who know that the day has come when America is privileged to spend her blood and her might for the principles that gave her birth and happiness and the peace which she has treasured. God helping her, she can do no other.'),
#  Document(id='9b32c76c-4306-4a85-bc44-1d07c51faefa', metadata={'source': 'speech.txt'}, page_content='things which we have always carried nearest our hearts—for democracy, for the right of those who submit to authority to have a voice in their own governments, for the rights and liberties of small nations, for a universal dominion of right by such a concert of free peoples as shall bring peace and safety to all nations and make the world itself at last free.'),
#  Document(id='9037bf5c-0395-4087-98a9-306e7dca9e64', metadata={'source': 'speech.txt'}, page_content='It is a distressing and oppressive duty, gentlemen of the Congress, which I have performed in thus addressing you. There are, it may be, many months of fiery trial and sacrifice ahead of us. It is a fearful thing to lead this great peaceful people into war, into the most terrible and disastrous of all wars, civilization itself seeming to be in the balance. But the right is more precious than peace, and we shall fight for the things which we have always carried nearest our hearts—for democracy,'),
#  Document(id='99aa0cab-1209-495d-b66f-faf36278f9c9', metadata={'source': 'speech.txt'}, page_content='it toward all who are in fact loyal to their neighbors and to the government in the hour of test. They are, most of them, as true and loyal Americans as if they had never known any other fealty or allegiance. They will be prompt to stand with us in rebuking and restraining the few who may be of a different mind and purpose. If there should be disloyalty, it will be dealt with with a firm hand of stern repression; but, if it lifts its head at all, it will lift it only here and there and without')]
