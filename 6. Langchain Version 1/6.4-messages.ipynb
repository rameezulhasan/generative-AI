# %%
import os 
from dotenv import load_dotenv
load_dotenv()

groq_key = os.getenv("GROQ_API_KEY")
from langchain.chat_models import init_chat_model
model = init_chat_model(
    "groq:openai/gpt-oss-120b"
)

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage
messages = [
    SystemMessage("You are cricket analyisis expert and you have to answer the questions related to cricket. you are very good at analyzing the cricket matches and you have to answer the questions related to cricket in a very detailed manner. you act like you was a cricket player and you have played many matches and you have a lot of experience in cricket."),
    HumanMessage("write poem on cricket in 100 words"),    
]
response = model.invoke(messages)
print(response.content)
# Out:
# Morning light kisses the emerald pitch,
# Leather meets willow, a thunderous stitch.
# Bowler charges, seam glides like a snake,
# Batsman eyes the horizon, dreams awake.
# A flick, a sweep, the ball kisses the sky,
# Crowd erupts, a chorus, a collective sigh.
# Fielders sprint, a blur of orange and green,
# A catch glints, destiny’s fleeting sheen.
# Spin twirls, a dancer’s graceful spin,
# Stumps shatter, a victory within.
# Heroes rise, legends etched in sand,
# Cricket’s heartbeat, a timeless band.
# Each run a story, each over a rhyme,
# In this sacred arena, we chase forever time.
# Echoes linger, hearts unite, love endures forever.

# %%
human_msg = HumanMessage(
    content="Hello",
    name="john",
    id ="123"
)

# %%
response = model.invoke([human_msg])
response
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'reasoning_content': 'The user says "Hello". We need to respond appropriately. It\'s a simple greeting. Should respond politely.'}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 72, 'total_tokens': 112, 'completion_time': 0.085724606, 'completion_tokens_details': {'reasoning_tokens': 22}, 'prompt_time': 0.002630845, 'prompt_tokens_details': None, 'queue_time': 0.332716656, 'total_time': 0.088355451}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_803c0ba83d', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f1b5b-c49b-7500-90a9-54e641950f56-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 72, 'output_tokens': 40, 'total_tokens': 112, 'output_token_details': {'reasoning': 22}})

# %%
response.usage_metadata
# Out:
# {'input_tokens': 72,
#  'output_tokens': 40,
#  'total_tokens': 112,
#  'output_token_details': {'reasoning': 22}}

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
print(response.content)
# Out:
# The current weather in San Francisco is sunny with a temperature of about **72 °F**. Enjoy the pleasant day!
